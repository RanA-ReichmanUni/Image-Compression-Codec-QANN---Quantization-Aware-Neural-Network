# %% [markdown]
# # Run

# %%
# !pip install diffusers==0.8.0
# !pip uninstall jax jaxlib -y
# Out:
# Collecting diffusers==0.8.0
#   Downloading diffusers-0.8.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.8.0) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.8.0) (3.16.1)
# Requirement already satisfied: huggingface-hub>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.8.0) (0.24.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers==0.8.0) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.8.0) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.8.0) (2.32.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.8.0) (10.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.8.0) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.8.0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.8.0) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.8.0) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.8.0) (4.12.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.8.0) (3.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.8.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.8.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.8.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.8.0) (2024.8.30)
# Downloading diffusers-0.8.0-py3-none-any.whl (433 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.8/433.8 kB 15.1 MB/s eta 0:00:00
# Installing collected packages: diffusers
# Successfully installed diffusers-0.8.0
# Found existing installation: jax 0.4.33
# Uninstalling jax-0.4.33:
#   Successfully uninstalled jax-0.4.33
# Found existing installation: jaxlib 0.4.33
# Uninstalling jaxlib-0.4.33:
#   Successfully uninstalled jaxlib-0.4.33

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Much better vae module
# Load VAE model
from diffusers import AutoencoderKL
device = "cuda:0"
vae = AutoencoderKL.from_pretrained("stabilityai/sd-vae-ft-mse").to(device)
vae.eval()
vae.half()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/diffusers/modeling_utils.py:90: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location="cpu")
# AutoencoderKL(
#   (encoder): Encoder(
#     (conv_in): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (down_blocks): ModuleList(
#       (0): DownEncoderBlock2D(
#         (resnets): ModuleList(
#           (0-1): 2 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (downsamplers): ModuleList(
#           (0): Downsample2D(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#       )
#       (1): DownEncoderBlock2D(
#         (resnets): ModuleList(
#           (0): ResnetBlock2D(
#             (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#             (conv_shortcut): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): ResnetBlock2D(
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (downsamplers): ModuleList(
#           (0): Downsample2D(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#       )
#       (2): DownEncoderBlock2D(
#         (resnets): ModuleList(
#           (0): ResnetBlock2D(
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#             (conv_shortcut): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): ResnetBlock2D(
#             (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (downsamplers): ModuleList(
#           (0): Downsample2D(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#       )
#       (3): DownEncoderBlock2D(
#         (resnets): ModuleList(
#           (0-1): 2 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#       )
#     )
#     (mid_block): UNetMidBlock2D(
#       (attentions): ModuleList(
#         (0): AttentionBlock(
#           (group_norm): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (query): Linear(in_features=512, out_features=512, bias=True)
#           (key): Linear(in_features=512, out_features=512, bias=True)
#           (value): Linear(in_features=512, out_features=512, bias=True)
#           (proj_attn): Linear(in_features=512, out_features=512, bias=True)
#         )
#       )
#       (resnets): ModuleList(
#         (0-1): 2 x ResnetBlock2D(
#           (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#     )
#     (conv_norm_out): GroupNorm(32, 512, eps=1e-06, affine=True)
#     (conv_act): SiLU()
#     (conv_out): Conv2d(512, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (decoder): Decoder(
#     (conv_in): Conv2d(4, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (up_blocks): ModuleList(
#       (0-1): 2 x UpDecoderBlock2D(
#         (resnets): ModuleList(
#           (0-2): 3 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (upsamplers): ModuleList(
#           (0): Upsample2D(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#       )
#       (2): UpDecoderBlock2D(
#         (resnets): ModuleList(
#           (0): ResnetBlock2D(
#             (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#             (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#             (conv_shortcut): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1-2): 2 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#         (upsamplers): ModuleList(
#           (0): Upsample2D(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           )
#         )
#       )
#       (3): UpDecoderBlock2D(
#         (resnets): ModuleList(
#           (0): ResnetBlock2D(
#             (norm1): GroupNorm(32, 256, eps=1e-06, affine=True)
#             (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#             (conv_shortcut): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1-2): 2 x ResnetBlock2D(
#             (norm1): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm2): GroupNorm(32, 128, eps=1e-06, affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (nonlinearity): SiLU()
#           )
#         )
#       )
#     )
#     (mid_block): UNetMidBlock2D(
#       (attentions): ModuleList(
#         (0): AttentionBlock(
#           (group_norm): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (query): Linear(in_features=512, out_features=512, bias=True)
#           (key): Linear(in_features=512, out_features=512, bias=True)
#           (value): Linear(in_features=512, out_features=512, bias=True)
#           (proj_attn): Linear(in_features=512, out_features=512, bias=True)
#         )
#       )
#       (resnets): ModuleList(
#         (0-1): 2 x ResnetBlock2D(
#           (norm1): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm2): GroupNorm(32, 512, eps=1e-06, affine=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (nonlinearity): SiLU()
#         )
#       )
#     )
#     (conv_norm_out): GroupNorm(32, 128, eps=1e-06, affine=True)
#     (conv_act): SiLU()
#     (conv_out): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (quant_conv): Conv2d(8, 8, kernel_size=(1, 1), stride=(1, 1))
#   (post_quant_conv): Conv2d(4, 4, kernel_size=(1, 1), stride=(1, 1))
# )

# %% [markdown]
# #Pixel Level Self Attention Model

# %%
# Install necessary libraries (if not already installed)
# !pip install ftfy pycocotools diffusers optuna

# Import Libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
from torch.cuda.amp import autocast
from diffusers import AutoencoderKL
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch.utils.checkpoint


class SelfAttention(nn.Module):
    def __init__(self, in_dim, downsample_factor=2):
        super(SelfAttention, self).__init__()
        self.in_dim = in_dim
        self.downsample_factor = downsample_factor
        self.query_conv = nn.Conv2d(in_dim, in_dim // 8, kernel_size=1)
        self.key_conv = nn.Conv2d(in_dim, in_dim // 8, kernel_size=1)
        self.value_conv = nn.Conv2d(in_dim, in_dim, kernel_size=1)
        self.gamma = nn.Parameter(torch.zeros(1))
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, x):
        batch, C, width, height = x.size()

        if not self.training:
            # Downsample the feature maps to reduce memory usage during inference
            x_down = F.interpolate(x, scale_factor=1 / self.downsample_factor, mode='bilinear', align_corners=False)
            width_down, height_down = x_down.size(2), x_down.size(3)
        else:
            x_down = x
            width_down, height_down = width, height

        # Compute projections
        proj_query = self.query_conv(x_down).view(batch, -1, width_down * height_down).permute(0, 2, 1)
        proj_key = self.key_conv(x_down).view(batch, -1, width_down * height_down)
        energy = torch.bmm(proj_query, proj_key)
        attention = self.softmax(energy)
        proj_value = self.value_conv(x_down).view(batch, -1, width_down * height_down)

        out = torch.bmm(proj_value, attention.permute(0, 2, 1))
        out = out.view(batch, C, width_down, height_down)

        if not self.training:
            # Upsample back to the original size
            out = F.interpolate(out, size=(width, height), mode='bilinear', align_corners=False)

        out = self.gamma * out + x
        return out
class UNetWithParams(nn.Module):
    def __init__(self, in_channels=3, out_channels=3):
        super(UNetWithParams, self).__init__()
        self.in_channels = in_channels

        self.param_fc = nn.Linear(1, 16)

        self.enc1 = self.conv_block(in_channels + 16, 64)
        self.enc2 = self.conv_block(64, 128)
        self.att1 = SelfAttention(128, downsample_factor=2)  # Adjusted attention
        self.enc3 = self.conv_block(128, 256)
        self.enc4 = self.conv_block(256, 512)

        self.bottleneck = self.conv_block(512, 1024)

        self.dec4 = self.up_conv(1024, 512)
        self.dec4_conv = self.conv_block(1024, 512)

        self.dec3 = self.up_conv(512, 256)
        self.dec3_conv = self.conv_block(512, 256)
        self.att2 = SelfAttention(256, downsample_factor=2)  # Adjusted attention

        self.dec2 = self.up_conv(256, 128)
        self.dec2_conv = self.conv_block(256, 128)

        self.dec1 = self.up_conv(128, 64)
        self.dec1_conv = self.conv_block(128, 64)

        self.final_conv = nn.Conv2d(64, out_channels, kernel_size=1)

    def conv_block(self, in_channels, out_channels):
        block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        return block

    def up_conv(self, in_channels, out_channels):
        up = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2)
        return up

    def forward(self, x, params):
        # Embed parameters
        param_embedding = self.param_fc(params)
        param_embedding = param_embedding.view(-1, 16, 1, 1)
        param_embedding = param_embedding.expand(-1, -1, x.size(2), x.size(3))
        x = torch.cat((x, param_embedding), dim=1)

        # Encoder
        e1 = self.enc1(x)
        e2 = self.enc2(F.max_pool2d(e1, 2))
        e2 = self.att1(e2)
        e3 = self.enc3(F.max_pool2d(e2, 2))
        e4 = self.enc4(F.max_pool2d(e3, 2))

        # Bottleneck
        b = self.bottleneck(F.max_pool2d(e4, 2))

        # Decoder
        d4 = self.dec4(b)
        d4 = torch.cat((d4, e4), dim=1)
        d4 = self.dec4_conv(d4)

        d3 = self.dec3(d4)
        d3 = torch.cat((d3, e3), dim=1)
        d3 = self.dec3_conv(d3)
        d3 = self.att2(d3)

        d2 = self.dec2(d3)
        d2 = torch.cat((d2, e2), dim=1)
        d2 = self.dec2_conv(d2)

        d1 = self.dec1(d2)
        d1 = torch.cat((d1, e1), dim=1)
        d1 = self.dec1_conv(d1)

        out = self.final_conv(d1)
        return out
# Out:
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (6.2.3)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.10/dist-packages (0.8.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (4.0.0)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy) (0.2.13)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.26.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers) (3.16.1)
# Requirement already satisfied: huggingface-hub>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.24.7)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers) (2.32.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers) (10.4.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.13.3)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.35)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.10.0->diffusers) (2024.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)

# %% [markdown]
# # Load Model

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
import torch

#model=UNetWithConditioning()
model=UNetWithParams()
# Path to your saved model (assuming it's in Google Drive as previously discussed)
model_path = '/content/drive/MyDrive/Models/PixelLevelRestorationVAECont2.1/unet_best_checkpoint.pth'

# Load the entire checkpoint (which contains more than just the model's state_dict)
checkpoint = torch.load(model_path)

# Extract only the model's state_dict from the checkpoint
model.load_state_dict(checkpoint['model_state_dict'])


# Set the model to evaluation mode if you’re doing inference
model.eval()


# model2=UNetWithConditioningResidual()

# # Path to your saved model (assuming it's in Google Drive as previously discussed)
# model_path = '/content/drive/MyDrive/Models/Model_Train3.1/unet_final_checkpoint.pth'

# # Load the entire checkpoint (which contains more than just the model's state_dict)
# checkpoint = torch.load(model_path)

# # Extract only the model's state_dict from the checkpoint
# model2.load_state_dict(checkpoint['model_state_dict'])


# # Set the model to evaluation mode if you’re doing inference
# model2.eval()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-12-95f994e46548>:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path)
# UNetWithParams(
#   (param_fc): Linear(in_features=1, out_features=16, bias=True)
#   (enc1): Sequential(
#     (0): Conv2d(19, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (enc2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (att1): SelfAttention(
#     (query_conv): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#     (key_conv): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#     (value_conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     (softmax): Softmax(dim=-1)
#   )
#   (enc3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (enc4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (bottleneck): Sequential(
#     (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (dec4): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2))
#   (dec4_conv): Sequential(
#     (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (dec3): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#   (dec3_conv): Sequential(
#     (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (att2): SelfAttention(
#     (query_conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#     (key_conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#     (value_conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (softmax): Softmax(dim=-1)
#   )
#   (dec2): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   (dec2_conv): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (dec1): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   (dec1_conv): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#   )
#   (final_conv): Conv2d(64, 3, kernel_size=(1, 1), stride=(1, 1))
# )

# %% [markdown]
# #Quantize

# %% [markdown]
# ## Load Files

# %%
def load_5125(image, left=0, right=0, top=0, bottom=0):
    # Convert image to NumPy array if necessary
    if isinstance(image, Image.Image):
        image = np.array(image)
    elif isinstance(image, torch.Tensor):
        image = image.permute(1, 2, 0).cpu().numpy()

    # Process image cropping
    h, w, _ = image.shape
    image = image[top:h - bottom, left:w - right]

    # Compute new dimensions while maintaining aspect ratio
    target_size = (768, 768)  # width, height
    scale = min(target_size[0] / w, target_size[1] / h)
    new_w = int(w * scale)
    new_h = int(h * scale)

    # Resize the image
    image_resized = Image.fromarray(image.astype(np.uint8)).resize((new_w, new_h), Image.BICUBIC)
    image_resized = np.array(image_resized)

    # Create a new image and paste the resized image into it
    image_padded = np.zeros((target_size[1], target_size[0], 3), dtype=np.uint8)
    pad_left = (target_size[0] - new_w) // 2
    pad_top = (target_size[1] - new_h) // 2
    image_padded[pad_top:pad_top + new_h, pad_left:pad_left + new_w, :] = image_resized

    # Convert to tensor and normalize
    image = torch.from_numpy(image_padded).float() / 255.0
    image = (image * 2.0) - 1.0
    image = image.permute(2, 0, 1)

    return image

def load_5123_CenterCropping(image, left=0, right=0, top=0, bottom=0):
    # If image is a PIL Image, convert to NumPy array
    if isinstance(image, Image.Image):
        image = np.array(image)
    elif isinstance(image, torch.Tensor):
        # Convert the tensor to NumPy array
        image = image.permute(1, 2, 0).cpu().numpy()

    # Process image cropping
    h, w, _ = image.shape
    left = min(left, w - 1)
    right = min(right, w - left - 1)
    top = min(top, h - 1)
    bottom = min(bottom, h - top - 1)
    image = image[top:h - bottom, left:w - right]

    # Handle aspect ratio and resize
    h, w, _ = image.shape
    if h < w:
        offset = (w - h) // 2
        image = image[:, offset:offset + h]
    elif w < h:
        offset = (h - w) // 2
        image = image[offset:offset + w]

    # Resize to 512x512
    image = Image.fromarray(image.astype(np.uint8)).resize((768, 768))
    image = np.array(image)

    # Convert back to PyTorch tensor and normalize
    image = torch.from_numpy(image).float() / 255.0  # Normalize to [0, 1]
    image = (image * 2.0) - 1.0  # Normalize to [-1, 1]
    image = image.permute(2, 0, 1)  # Adjust dimensions for PyTorch [C, H, W]

    return image  # Do not move to device here

import numpy as np
import torch
from PIL import Image



def simple_load(img, target_size=(512, 512)):
    # Convert image to PIL Image if it's not already
    if not isinstance(img, Image.Image):
        img = Image.fromarray(img)

    # Resize the image directly to the target size without maintaining aspect ratio
    img_resized = img.resize(target_size, Image.LANCZOS)

    # Convert the resized image to a PyTorch tensor and normalize
    image_tensor = torch.from_numpy(np.array(img_resized)).float() / 255.0  # Normalize to [0, 1]
    image_tensor = (image_tensor * 2.0) - 1.0  # Normalize to [-1, 1]
    image_tensor = image_tensor.permute(2, 0, 1)  # Adjust dimensions to [C, H, W]

    # Return both the image tensor and the resized PIL Image
    return image_tensor, img_resized

# %% [markdown]
# ## Quantization Function

# %%
from utils import image_grid
# !pip install brotli
import brotli
import zlib
import numpy as np
import torch
from PIL import Image
from torch.cuda.amp import autocast

def quantize(latents, parameter=0.58215):
    quantized_latents = (latents / (255 * parameter) + 0.5).clamp(0, 1)
    quantized = quantized_latents.cpu().permute(0, 2, 3, 1).detach().numpy()[0]
    quantized = (quantized * 255.0 + 0.5).astype(np.uint8)
    return quantized

def unquantize(quantized, parameter=0.58215):
    unquantized = quantized.astype(np.float32) / 255.0
    unquantized = unquantized[None].transpose(0, 3, 1, 2)
    unquantized_latents = (unquantized - 0.5) * (255 * parameter)
    unquantized_latents = torch.from_numpy(unquantized_latents)
    return unquantized_latents.to(device)

def quantize_function(image_path, model, parameter = 0.58215, target_bpp=0.15, tolerance=0.005, max_iterations=20):
    offsets = (0, 0, 0, 0)  # Offset for image loading
    image_gt_path = image_path
    img = Image.open(image_gt_path).convert('RGB')
    x0 = load_5123_CenterCropping(img)  # Load and preprocess image
    x0 = x0.half().to(device)  # Ensure the input is in half precision
    x0 = x0.unsqueeze(0)

    with autocast(enabled=True):
        w0 = (vae.encode(x0).latent_dist.mode() * 0.18215).float()


    best_parameter = parameter
    best_bpp = float('inf')
    best_quantized = None

    for iteration in range(max_iterations):
        quantized = quantize(w0, parameter)

        # Move tensor to CPU (if on GPU) and convert to numpy array
        latents_numpy = quantized

        # Convert numpy array to byte stream
        latents_bytes = latents_numpy.tobytes()

        # Compress the byte stream using brotli (you could use zlib or both as needed)
        compressed_bytes = brotli.compress(latents_bytes, quality=11)

        # Calculate bpp
        image_pixels = 768 * 768  # Get image size (width * height)
        bpp = (len(compressed_bytes) * 8) / image_pixels  # Convert bytes to bits and divide by number of pixels

        print(f"Iteration {iteration + 1}: Parameter = {parameter}, Brotli Compressed bpp = {bpp:.6f}")

        # Check if this is the closest bpp we've achieved
        if abs(bpp - target_bpp) < abs(best_bpp - target_bpp):
            best_bpp = bpp
            best_parameter = parameter
            best_quantized = quantized

        # Check if we've reached the target bpp within the tolerance
        if abs(bpp - target_bpp) <= tolerance:
            print("Target bpp reached!")
            break

        # Adjust the parameter to get closer to the target bpp
        if bpp > target_bpp:
            parameter *= 1.1  # Increase parameter to lower bpp
        else:
            parameter *= 0.9  # Decrease parameter to raise bpp

    # Save the best quantized latents
    latents_numpy = best_quantized

    # Store the dtype and shape of the array
    latents_dtype = latents_numpy.dtype
    latents_shape = latents_numpy.shape

    # Convert numpy array to byte stream and compress
    latents_bytes = latents_numpy.tobytes()
    compressed_bytes = brotli.compress(latents_bytes, quality=11)

    # Save the compressed latents
    with open("compressed_latents.bin", "wb") as f:
        f.write(compressed_bytes)

    # Save the dtype and shape for later use
    np.savez("latents_metadata.npz", dtype=latents_dtype.name, shape=latents_shape)

    # Load the compressed data and metadata
    with open("compressed_latents.bin", "rb") as f:
        compressed_latents = f.read()

    # Load the metadata
    metadata = np.load("latents_metadata.npz")
    latents_dtype_name = metadata['dtype'].item()
    latents_shape = tuple(metadata['shape'])
    latents_dtype = np.dtype(latents_dtype_name)

    # Decompress the data
    decompressed_bytes = brotli.decompress(compressed_latents)
    decompressed_numpy = np.frombuffer(decompressed_bytes, dtype=latents_dtype)
    decompressed_numpy = decompressed_numpy.reshape(latents_shape)

    latents1 = unquantize(decompressed_numpy, best_parameter)
    model = model.to(device)
    noise_level = torch.tensor([best_parameter], dtype=torch.float32).to(device)  # Single value for noise level
    latents1=latents1.half()
    # Decode the image using VAE
    with torch.no_grad():
       # Decode the unquantized latents to images

        decoded_unquantized_images = vae.decode(1 / 0.18215 * (latents1 )).sample

        # Model prediction
        residual_tensor = model(decoded_unquantized_images, noise_level)

        # Reconstructed images
        x0_dec = decoded_unquantized_images + residual_tensor

    img = image_grid(x0_dec)  # Create an image grid for the decoded image

    return img
# Out:
# Requirement already satisfied: brotli in /usr/local/lib/python3.10/dist-packages (1.1.0)

# %% [markdown]
# #PSNR

# %%
from skimage.metrics import structural_similarity as get_ssim
from skimage.metrics import peak_signal_noise_ratio as get_psnr
from PIL import Image

def psnr_function(gt, img):
    gt_array = np.array(gt)
    img_array = np.array(img)

    # Debugging dimensions and channels
    print(f"GT Image Shape: {gt_array.shape}, Processed Image Shape: {img_array.shape}")

    # Check dimensions and channels
    if gt_array.ndim != 3 or img_array.ndim != 3:
        print("Error: Images must have three dimensions (height, width, channels).")
        return
    if gt_array.shape[0] < 7 or gt_array.shape[1] < 7 or img_array.shape[0] < 7 or img_array.shape[1] < 7:
        print("Warning: Images are too small for SSIM calculation. Ensure images are at least 7x7 pixels.")
        return

    # Ensure images have three channels
    if gt_array.shape[2] != 3 or img_array.shape[2] != 3:
        print("Error: Images must have three channels.")
        return

    # Calculate metrics with explicitly set parameters
    try:
        psnr_value = get_psnr(gt_array, img_array)
        ssim_value = get_ssim(gt_array, img_array, win_size=7, multichannel=True, channel_axis=2, data_range=img_array.max() - img_array.min())
        return psnr_value, ssim_value

    except Exception as e:
        print("Failed to calculate metrics:", str(e))

# %% [markdown]
# # Average

# %%
import os
from PIL import Image
import numpy as np

def load_with_aspect_ratio2(img, target_size=(512, 512)):
    image = np.array(img)
    h, w, _ = image.shape

    # Calculate the scaling factor
    scale = min(target_size[0] / h, target_size[1] / w)
    new_size = (int(w * scale), int(h * scale))

    # Resize the image
    image = Image.fromarray(image).resize(new_size, Image.LANCZOS)
    image = np.array(image)

    # Create a new image with the target size and paste the resized image
    new_image = np.zeros((target_size[1], target_size[0], 3), dtype=np.uint8)
    offset_y = (target_size[1] - new_size[1]) // 2
    offset_x = (target_size[0] - new_size[0]) // 2
    new_image[offset_y:offset_y + new_size[1], offset_x:offset_x + new_size[0]] = image

    # Convert to PyTorch tensor and normalize
    image = Image.fromarray(new_image)

    return image

# Custom Preprocessing Function
def load_5123_CenterCropping2(image_path, left=0, right=0, top=0, bottom=0):
    image=Image.open(image_path).convert('RGB')
    # If image is a PIL Image, convert to NumPy array
    if isinstance(image, Image.Image):
        image = np.array(image)
    elif isinstance(image, torch.Tensor):
        # Convert the tensor to NumPy array
        image = image.permute(1, 2, 0).cpu().numpy()

    # Process image cropping
    h, w, _ = image.shape
    left = min(left, w - 1)
    right = min(right, w - left - 1)
    top = min(top, h - 1)
    bottom = min(bottom, h - top - 1)
    image = image[top:h - bottom, left:w - right]

    # Handle aspect ratio and resize
    h, w, _ = image.shape
    if h < w:
        offset = (w - h) // 2
        image = image[:, offset:offset + h]
    elif w < h:
        offset = (h - w) // 2
        image = image[offset:offset + w]

    # Resize to 512x512
    image = Image.fromarray(image.astype(np.uint8)).resize((768, 768))

    return image  # Do not move to device here


def load_5122(image_path, left=0, right=0, top=0, bottom=0):
    # Load image
    if isinstance(image_path, str):
        image = Image.open(image_path).convert('RGB')
    elif isinstance(image_path, Image.Image):
        image = image_path
    else:
        raise ValueError("Input must be a file path or PIL Image.")

    # Convert to NumPy array
    image = np.array(image)

    # Process image cropping
    h, w, c = image.shape
    left = min(left, w - 1)
    right = min(right, w - left - 1)
    top = min(top, h - 1)
    bottom = min(bottom, h - top - 1)
    image = image[top:h - bottom, left:w - right]

    # Compute new dimensions while maintaining aspect ratio
    target_size = (768, 768)  # width, height
    scale = min(target_size[0] / w, target_size[1] / h)
    new_w = int(w * scale)
    new_h = int(h * scale)

    # Resize the image
    image_resized = Image.fromarray(image.astype(np.uint8)).resize((new_w, new_h), Image.BICUBIC)

    # Create a new image and paste the resized image into it
    image_padded = Image.new('RGB', target_size, (0, 0, 0))  # You can change the fill color if needed
    pad_left = (target_size[0] - new_w) // 2
    pad_top = (target_size[1] - new_h) // 2
    image_padded.paste(image_resized, (pad_left, pad_top))

    return image_padded  # Returns a PIL Image object



# Custom Preprocessing Function
def load_5124(image, left=0, right=0, top=0, bottom=0):

    image = np.array(image)[:, :, :3]


    h, w, c = image.shape
    left = min(left, w-1)
    right = min(right, w - left - 1)
    top = min(top, h - left - 1)
    bottom = min(bottom, h - top - 1)
    image = image[top:h-bottom, left:w-right]
    h, w, c = image.shape
    if h < w:
        offset = (w - h) // 2
        image = image[:, offset:offset + h]
    elif w < h:
        offset = (h - w) // 2
        image = image[offset:offset + w]
    image = Image.fromarray(image).resize((768, 768))
    return image

def calculate_average_psnr(folder_path):
    """
    Calculate the average PSNR after quantizing all images in a folder.

    Parameters:
    folder_path (str): The path to the folder containing the images.
    quantize_function (function): The function to quantize the images.
    psnr_function (function): The function to calculate PSNR between two images.

    Returns:
    float: The average PSNR across all images.
    """
    psnr_sum = 0
    ssim_sum = 0
    image_count = 0

    # Iterate over all files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            # Load the image
            image_path = os.path.join(folder_path, filename)
            image=Image.open(image_path).convert('RGB')
            original_image = load_5123_CenterCropping2(image_path)


            # Quantize the imag
            quantized_image =  quantize_function(image_path, model, target_bpp=0.25, tolerance=0.0005, max_iterations=20)
            #quantized_image=load_5124(quantized_image)
            # Calculate PSNR
            psnr_value, ssim_value = psnr_function(original_image, quantized_image)
            psnr_sum += psnr_value
            ssim_sum += ssim_value
            image_count += 1
    display(original_image)
    display(quantized_image)
    # Calculate the average PSNR
    if image_count == 0:
        return 0.0  # Avoid division by zero if no images were found

    average_psnr = psnr_sum / image_count
    average_ssim = ssim_sum / image_count
    print(f"Average PSNR: {average_psnr}")
    print(f"Average SSIM: {average_ssim}")
    return average_psnr
calculate_average_psnr("/content/")
# Out:
# <ipython-input-5-9a172169b412>:31: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=True):
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.147664
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.156250
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.166368
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.175944
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.185371
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.194906
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.204983
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.214966
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.225532
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.236382
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.246908
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.256022
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.247694
# Iteration 14: Parameter = 0.1808579901286556, Brotli Compressed bpp = 0.256904
# Iteration 15: Parameter = 0.1989437891415212, Brotli Compressed bpp = 0.247830
# Iteration 16: Parameter = 0.1790494102273691, Brotli Compressed bpp = 0.258531
# Iteration 17: Parameter = 0.19695435125010602, Brotli Compressed bpp = 0.249552
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.162286
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.171387
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.181708
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.191515
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.200480
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.209880
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.219035
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.228692
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.238688
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.248237
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.258206
# Iteration 12: Parameter = 0.22328146929463652, Brotli Compressed bpp = 0.249702
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.152696
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.162815
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.172133
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.181695
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.191583
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.200412
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.209703
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.219455
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.228800
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.238756
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.247776
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.257840
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.249010
# Iteration 14: Parameter = 0.1808579901286556, Brotli Compressed bpp = 0.258599
# Iteration 15: Parameter = 0.1989437891415212, Brotli Compressed bpp = 0.250095
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.165785
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.174466
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.183309
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.192803
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.202284
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.211656
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.219876
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.228882
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.238186
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.247125
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.256877
# Iteration 12: Parameter = 0.22328146929463652, Brotli Compressed bpp = 0.248820
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.258409
# Iteration 14: Parameter = 0.22104865460169018, Brotli Compressed bpp = 0.249580
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.141222
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.151232
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.160685
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.170261
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.180705
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.191366
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.201945
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.212050
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.223565
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.234361
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.245470
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.257433
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.247301
# Iteration 14: Parameter = 0.1808579901286556, Brotli Compressed bpp = 0.258464
# Iteration 15: Parameter = 0.1989437891415212, Brotli Compressed bpp = 0.247233
# Iteration 16: Parameter = 0.1790494102273691, Brotli Compressed bpp = 0.259481
# Iteration 17: Parameter = 0.19695435125010602, Brotli Compressed bpp = 0.248413
# Iteration 18: Parameter = 0.17725891612509542, Brotli Compressed bpp = 0.259616
# Iteration 19: Parameter = 0.194984807737605, Brotli Compressed bpp = 0.250556
# Iteration 20: Parameter = 0.2144832885113655, Brotli Compressed bpp = 0.240004
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.143487
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.151923
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.162150
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.172106
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.182075
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.191623
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.201769
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.212172
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.222792
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.231906
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.242106
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.254503
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.243300
# Iteration 14: Parameter = 0.1808579901286556, Brotli Compressed bpp = 0.254272
# Iteration 15: Parameter = 0.1989437891415212, Brotli Compressed bpp = 0.245144
# Iteration 16: Parameter = 0.1790494102273691, Brotli Compressed bpp = 0.255330
# Iteration 17: Parameter = 0.19695435125010602, Brotli Compressed bpp = 0.245592
# Iteration 18: Parameter = 0.17725891612509542, Brotli Compressed bpp = 0.256198
# Iteration 19: Parameter = 0.194984807737605, Brotli Compressed bpp = 0.246935
# Iteration 20: Parameter = 0.1754863269638445, Brotli Compressed bpp = 0.257907
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.158841
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.168918
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.177477
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.187826
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.196370
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.206177
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.215671
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.225423
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.235311
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.245687
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.254015
# Iteration 12: Parameter = 0.22328146929463652, Brotli Compressed bpp = 0.246148
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.255154
# Iteration 14: Parameter = 0.22104865460169018, Brotli Compressed bpp = 0.247057
# Iteration 15: Parameter = 0.19894378914152117, Brotli Compressed bpp = 0.256293
# Iteration 16: Parameter = 0.2188381680556733, Brotli Compressed bpp = 0.247965
# Iteration 17: Parameter = 0.19695435125010596, Brotli Compressed bpp = 0.257284
# Iteration 18: Parameter = 0.2166497863751166, Brotli Compressed bpp = 0.248928
# Iteration 19: Parameter = 0.19498480773760493, Brotli Compressed bpp = 0.257189
# Iteration 20: Parameter = 0.21448328851136544, Brotli Compressed bpp = 0.249580
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.143012
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.151408
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.161879
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.172485
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.180854
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.190782
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.199910
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.209975
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.219604
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.229913
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.240139
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.250027
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.148261
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.156874
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.166165
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.174954
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.183797
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.193997
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.203342
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.213677
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.222683
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.233181
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.242499
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.251221
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.243327
# Iteration 14: Parameter = 0.1808579901286556, Brotli Compressed bpp = 0.252496
# Iteration 15: Parameter = 0.1989437891415212, Brotli Compressed bpp = 0.244046
# Iteration 16: Parameter = 0.1790494102273691, Brotli Compressed bpp = 0.253120
# Iteration 17: Parameter = 0.19695435125010602, Brotli Compressed bpp = 0.244846
# Iteration 18: Parameter = 0.17725891612509542, Brotli Compressed bpp = 0.253540
# Iteration 19: Parameter = 0.194984807737605, Brotli Compressed bpp = 0.245850
# Iteration 20: Parameter = 0.1754863269638445, Brotli Compressed bpp = 0.255222
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.155653
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.165690
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.174642
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.184692
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.194200
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.203084
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.212769
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.222833
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.233263
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.243598
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.253133
# Iteration 12: Parameter = 0.22328146929463652, Brotli Compressed bpp = 0.244453
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.253581
# Iteration 14: Parameter = 0.22104865460169018, Brotli Compressed bpp = 0.244954
# Iteration 15: Parameter = 0.19894378914152117, Brotli Compressed bpp = 0.255344
# Iteration 16: Parameter = 0.2188381680556733, Brotli Compressed bpp = 0.246650
# Iteration 17: Parameter = 0.19695435125010596, Brotli Compressed bpp = 0.255859
# Iteration 18: Parameter = 0.2166497863751166, Brotli Compressed bpp = 0.247138
# Iteration 19: Parameter = 0.19498480773760493, Brotli Compressed bpp = 0.256497
# Iteration 20: Parameter = 0.21448328851136544, Brotli Compressed bpp = 0.248142
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.119073
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.128784
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.139228
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.148831
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.157349
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.167575
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.177667
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.188246
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.199626
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.209486
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.218777
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.230645
# Iteration 13: Parameter = 0.16441635466241417, Brotli Compressed bpp = 0.240967
# Iteration 14: Parameter = 0.14797471919617275, Brotli Compressed bpp = 0.251004
# Iteration 15: Parameter = 0.16277219111579003, Brotli Compressed bpp = 0.241319
# Iteration 16: Parameter = 0.14649497200421102, Brotli Compressed bpp = 0.251845
# Iteration 17: Parameter = 0.16114446920463213, Brotli Compressed bpp = 0.242554
# Iteration 18: Parameter = 0.14503002228416892, Brotli Compressed bpp = 0.252821
# Iteration 19: Parameter = 0.15953302451258583, Brotli Compressed bpp = 0.244059
# Iteration 20: Parameter = 0.14357972206132724, Brotli Compressed bpp = 0.254462
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.145915
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.155206
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.163832
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.173570
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.182671
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.192491
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.201430
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.210409
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.219794
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.230197
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.240085
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.249688
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.146010
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.152941
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.163384
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.173367
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.182671
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.192451
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.200941
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.210924
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.220378
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.229980
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.239909
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.249661
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.150146
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.157837
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.167006
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.176500
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.185954
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.195014
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.204888
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.214044
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.223904
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.233290
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.243856
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.253106
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.244385
# Iteration 14: Parameter = 0.1808579901286556, Brotli Compressed bpp = 0.254584
# Iteration 15: Parameter = 0.1989437891415212, Brotli Compressed bpp = 0.245605
# Iteration 16: Parameter = 0.1790494102273691, Brotli Compressed bpp = 0.255113
# Iteration 17: Parameter = 0.19695435125010602, Brotli Compressed bpp = 0.246501
# Iteration 18: Parameter = 0.17725891612509542, Brotli Compressed bpp = 0.256212
# Iteration 19: Parameter = 0.194984807737605, Brotli Compressed bpp = 0.247654
# Iteration 20: Parameter = 0.1754863269638445, Brotli Compressed bpp = 0.257134
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.150418
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.160156
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.169569
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.179104
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.187405
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.197984
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.206896
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.217773
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.226549
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.236247
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.245999
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.255344
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.247016
# Iteration 14: Parameter = 0.1808579901286556, Brotli Compressed bpp = 0.256700
# Iteration 15: Parameter = 0.1989437891415212, Brotli Compressed bpp = 0.247545
# Iteration 16: Parameter = 0.1790494102273691, Brotli Compressed bpp = 0.257718
# Iteration 17: Parameter = 0.19695435125010602, Brotli Compressed bpp = 0.248711
# Iteration 18: Parameter = 0.17725891612509542, Brotli Compressed bpp = 0.258653
# Iteration 19: Parameter = 0.194984807737605, Brotli Compressed bpp = 0.249580
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.140666
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.148736
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.156236
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.164849
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.174954
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.184448
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.193658
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.203247
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.211724
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.220676
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.230252
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.239678
# Iteration 13: Parameter = 0.16441635466241417, Brotli Compressed bpp = 0.249851
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.157566
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.166328
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.176500
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.185398
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.195882
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.205024
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.214206
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.223551
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.233412
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.243490
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.253988
# Iteration 12: Parameter = 0.22328146929463652, Brotli Compressed bpp = 0.244439
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.254951
# Iteration 14: Parameter = 0.22104865460169018, Brotli Compressed bpp = 0.245497
# Iteration 15: Parameter = 0.19894378914152117, Brotli Compressed bpp = 0.255439
# Iteration 16: Parameter = 0.2188381680556733, Brotli Compressed bpp = 0.246270
# Iteration 17: Parameter = 0.19695435125010596, Brotli Compressed bpp = 0.256388
# Iteration 18: Parameter = 0.2166497863751166, Brotli Compressed bpp = 0.247165
# Iteration 19: Parameter = 0.19498480773760493, Brotli Compressed bpp = 0.257623
# Iteration 20: Parameter = 0.21448328851136544, Brotli Compressed bpp = 0.248372
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.149156
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.157742
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.167074
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.177205
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.186795
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.195991
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.205526
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.215264
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.225125
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.234673
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.245294
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.254693
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.245551
# Iteration 14: Parameter = 0.1808579901286556, Brotli Compressed bpp = 0.256158
# Iteration 15: Parameter = 0.1989437891415212, Brotli Compressed bpp = 0.246799
# Iteration 16: Parameter = 0.1790494102273691, Brotli Compressed bpp = 0.256877
# Iteration 17: Parameter = 0.19695435125010602, Brotli Compressed bpp = 0.247965
# Iteration 18: Parameter = 0.17725891612509542, Brotli Compressed bpp = 0.257568
# Iteration 19: Parameter = 0.194984807737605, Brotli Compressed bpp = 0.248698
# Iteration 20: Parameter = 0.1754863269638445, Brotli Compressed bpp = 0.258165
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.117133
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.127319
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.137234
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.149061
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.159519
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.169542
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.180786
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.192247
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.202393
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.213243
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.221381
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.230930
# Iteration 13: Parameter = 0.16441635466241417, Brotli Compressed bpp = 0.242472
# Iteration 14: Parameter = 0.14797471919617275, Brotli Compressed bpp = 0.250434
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.157783
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.167141
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.176649
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.186768
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.197116
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.205743
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.216648
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.226061
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.235067
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.245551
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.255452
# Iteration 12: Parameter = 0.22328146929463652, Brotli Compressed bpp = 0.246663
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.256158
# Iteration 14: Parameter = 0.22104865460169018, Brotli Compressed bpp = 0.247233
# Iteration 15: Parameter = 0.19894378914152117, Brotli Compressed bpp = 0.257161
# Iteration 16: Parameter = 0.2188381680556733, Brotli Compressed bpp = 0.248332
# Iteration 17: Parameter = 0.19695435125010596, Brotli Compressed bpp = 0.258206
# Iteration 18: Parameter = 0.2166497863751166, Brotli Compressed bpp = 0.249417
# Iteration 19: Parameter = 0.19498480773760493, Brotli Compressed bpp = 0.259182
# Iteration 20: Parameter = 0.21448328851136544, Brotli Compressed bpp = 0.250380
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.134210
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.143731
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.152873
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.160780
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.170939
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.181437
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.190077
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.200833
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.210910
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.221056
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.231350
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.240099
# Iteration 13: Parameter = 0.16441635466241417, Brotli Compressed bpp = 0.251641
# Iteration 14: Parameter = 0.1808579901286556, Brotli Compressed bpp = 0.240262
# Iteration 15: Parameter = 0.16277219111579005, Brotli Compressed bpp = 0.252089
# Iteration 16: Parameter = 0.1790494102273691, Brotli Compressed bpp = 0.242255
# Iteration 17: Parameter = 0.16114446920463218, Brotli Compressed bpp = 0.252672
# Iteration 18: Parameter = 0.17725891612509542, Brotli Compressed bpp = 0.243707
# Iteration 19: Parameter = 0.15953302451258589, Brotli Compressed bpp = 0.253337
# Iteration 20: Parameter = 0.1754863269638445, Brotli Compressed bpp = 0.244263
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.153768
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.162842
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.171495
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.181166
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.190837
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.200141
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.208713
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.217556
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.227064
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.236654
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.246799
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.256185
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.248237
# Iteration 14: Parameter = 0.1808579901286556, Brotli Compressed bpp = 0.257026
# Iteration 15: Parameter = 0.1989437891415212, Brotli Compressed bpp = 0.248467
# Iteration 16: Parameter = 0.1790494102273691, Brotli Compressed bpp = 0.258111
# Iteration 17: Parameter = 0.19695435125010602, Brotli Compressed bpp = 0.249376
# Iteration 18: Parameter = 0.17725891612509542, Brotli Compressed bpp = 0.259115
# Iteration 19: Parameter = 0.194984807737605, Brotli Compressed bpp = 0.250393
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.156942
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.165392
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.175076
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.184313
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.193604
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.203071
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.212253
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.220310
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.229546
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.239516
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.249213
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.258993
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.250258
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.126451
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.139242
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.146742
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.156481
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.163778
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.174398
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.183051
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.191989
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.202447
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.213609
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.223063
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.233927
# Iteration 13: Parameter = 0.16441635466241417, Brotli Compressed bpp = 0.244561
# Iteration 14: Parameter = 0.14797471919617275, Brotli Compressed bpp = 0.255412
# Iteration 15: Parameter = 0.16277219111579003, Brotli Compressed bpp = 0.245199
# Iteration 16: Parameter = 0.14649497200421102, Brotli Compressed bpp = 0.256605
# Iteration 17: Parameter = 0.16114446920463213, Brotli Compressed bpp = 0.247192
# Iteration 18: Parameter = 0.14503002228416892, Brotli Compressed bpp = 0.257528
# Iteration 19: Parameter = 0.15953302451258583, Brotli Compressed bpp = 0.247816
# Iteration 20: Parameter = 0.14357972206132724, Brotli Compressed bpp = 0.258925
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.133952
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.142442
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.150865
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.160224
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.169596
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.179511
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.189195
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.199056
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.209785
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.219170
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.229451
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.239990
# Iteration 13: Parameter = 0.16441635466241417, Brotli Compressed bpp = 0.248576
# Iteration 14: Parameter = 0.14797471919617275, Brotli Compressed bpp = 0.257636
# Iteration 15: Parameter = 0.16277219111579003, Brotli Compressed bpp = 0.249227
# Iteration 16: Parameter = 0.14649497200421102, Brotli Compressed bpp = 0.260091
# Iteration 17: Parameter = 0.16114446920463213, Brotli Compressed bpp = 0.251397
# Iteration 18: Parameter = 0.17725891612509537, Brotli Compressed bpp = 0.242527
# Iteration 19: Parameter = 0.15953302451258583, Brotli Compressed bpp = 0.251600
# Iteration 20: Parameter = 0.17548632696384442, Brotli Compressed bpp = 0.243123
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.158637
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.167942
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.177205
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.186998
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.195719
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.204861
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.213745
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.222656
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.232585
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.242188
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.252007
# Iteration 12: Parameter = 0.22328146929463652, Brotli Compressed bpp = 0.243150
# Iteration 13: Parameter = 0.20095332236517288, Brotli Compressed bpp = 0.253174
# Iteration 14: Parameter = 0.22104865460169018, Brotli Compressed bpp = 0.244113
# Iteration 15: Parameter = 0.19894378914152117, Brotli Compressed bpp = 0.254096
# Iteration 16: Parameter = 0.2188381680556733, Brotli Compressed bpp = 0.244927
# Iteration 17: Parameter = 0.19695435125010596, Brotli Compressed bpp = 0.254856
# Iteration 18: Parameter = 0.2166497863751166, Brotli Compressed bpp = 0.245985
# Iteration 19: Parameter = 0.19498480773760493, Brotli Compressed bpp = 0.255778
# Iteration 20: Parameter = 0.21448328851136544, Brotli Compressed bpp = 0.247057
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.153266
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.163018
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.171631
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.180583
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.190036
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.200046
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.209486
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.219496
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.229045
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.239434
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.250149
# Target bpp reached!
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.143460
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.152167
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.160821
# Iteration 4: Parameter = 0.42438734999999994, Brotli Compressed bpp = 0.170654
# Iteration 5: Parameter = 0.38194861499999994, Brotli Compressed bpp = 0.179742
# Iteration 6: Parameter = 0.3437537534999999, Brotli Compressed bpp = 0.189399
# Iteration 7: Parameter = 0.30937837814999997, Brotli Compressed bpp = 0.198798
# Iteration 8: Parameter = 0.278440540335, Brotli Compressed bpp = 0.208442
# Iteration 9: Parameter = 0.2505964863015, Brotli Compressed bpp = 0.216946
# Iteration 10: Parameter = 0.22553683767135, Brotli Compressed bpp = 0.226088
# Iteration 11: Parameter = 0.202983153904215, Brotli Compressed bpp = 0.235189
# Iteration 12: Parameter = 0.18268483851379352, Brotli Compressed bpp = 0.245036
# Iteration 13: Parameter = 0.16441635466241417, Brotli Compressed bpp = 0.254639
# Iteration 14: Parameter = 0.1808579901286556, Brotli Compressed bpp = 0.245456
# Iteration 15: Parameter = 0.16277219111579005, Brotli Compressed bpp = 0.255764
# Iteration 16: Parameter = 0.1790494102273691, Brotli Compressed bpp = 0.246894
# Iteration 17: Parameter = 0.16114446920463218, Brotli Compressed bpp = 0.256009
# Iteration 18: Parameter = 0.17725891612509542, Brotli Compressed bpp = 0.247545
# Iteration 19: Parameter = 0.15953302451258589, Brotli Compressed bpp = 0.257541
# Iteration 20: Parameter = 0.1754863269638445, Brotli Compressed bpp = 0.248562
# GT Image Shape: (768, 768, 3), Processed Image Shape: (768, 768, 3)
# Iteration 1: Parameter = 0.58215, Brotli Compressed bpp = 0.160699
# Iteration 2: Parameter = 0.5239349999999999, Brotli Compressed bpp = 0.170234
# Iteration 3: Parameter = 0.47154149999999995, Brotli Compressed bpp = 0.180230
